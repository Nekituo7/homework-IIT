# %% [markdown]
# # Титульный лист
# <a name = 'Титульный_лист'>

# %% [markdown]
# <font face="times new roman" size="3" color="black">
# <center> МИНИСТЕРСТВО ЦИФРОВОГО РАЗВИТИЯ, СВЯЗИ И МАССОВЫХ КОММУНИКАЦИЙ РОССИЙСКОЙ ФЕДЕРАЦИИ </center>
# <center>Ордена Трудового Красного Знамени федеральное государственное бюджетное образовательное учреждение высшего образования </center>
# <center> <strong> «Московский технический университет связи и информатики» </strong> </center>
#
# <center> Кафедра «Телевидения и звукового вещания им. С.И. Катаева (ТиЗВ)» </center>
# <br>
# <center> <font face="times new roman" size="3" color="black"> Отчет по практической работе №12 </center>
# <center>по дисциплине </center>
# <center><b>«Введение в информационные технологии»</b></center>
# <center>на тему</center>
# <center><b>«Системы контроля версий.»</b> </center>
#
# </font>
#
#   <br><br><br><br><br>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Выполнил: студент группы </p>
#   <p  align="right"> <font face="times new roman" size="3" color="black">       БИК2303 </p>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Григорьев Никита Алексеевич</p>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Проверил:</p>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Ассистент кафедры ТиЗВ Кудряшов Всеволод Владимирович </p>
#   <br>
#   <br>
#
#   <p  align="center"> <font face="times new roman" size="2" color="black"> Москва, 2023 г. </p>
#
#   <hr>

# %% [markdown]
# # Содержание

# %% [markdown]
# <ol type="none">
# <li><a href = '#Постановка_задач'> Постановка задач </a>
# <ul>
#       <li><a href = '##1'> Задание </a>
#       <li><a href = '##2'> Цель работы </a>
#       <li><a href = '##3'> Задачи работы </a>
#       <li><a href = '##4'> Расчет входных данных</a>
# </ul>
# <li><a href = '#ход_работы'> Ход работы </a>
# <ul>
#       <li><a href = '#Задание_№1'> Задание №1 </a>
#       <li><a href = '#Задание_№2'> Задание №2 </a>
#       <li><a href = '#Задание_№3'> Задание №3 </a>
#       <li><a href = '#Задание_№4'> Задание №4 </a>
#       <li><a href = '#Задание_№5'> Задание №5 </a>
#       <li><a href = '#Задание_№6'> Задание №6 </a>
#       <li><a href = '#Задание_№7'> Задание №7 </a>
#       <li><a href = '#Задание_№8'> Задание №8 </a>
#       <li><a href = '#Задание_№8'> Задание №9 </a>
# </ul>
# <li><a href = '#Результат_выполнения'> Результат выполнения работы </a>
# <li><a href = '#Контрольное_задание'> Контрольное задание на защиту </a>

# %% [markdown]
# <a name = 'Постановка_задач'></a>
# # Постановка задач

# %% [markdown]
# <a name = '#1'></a>
# ## Задания
#
# 1. Установить GIT.
# 1. Создать локальный репозиторий.
# 1. Создать файл отчета по выполнению практической работы и поместить его в репозиторий.
# 1. Зафиксировать в отчете все проделанные шаги и создать версию отчета в GIT.
# 1. Создать ветку отчета в GIT, добавить описание шагов в отчет и создать версию отчета в новой ветке.
# 1. Слить последнее изменение отчета в основную ветку.
# 1. Зарегистрироваться на github (или использовать уже существующий аккаунт), создать проект «homework IIT», залить содержимое из локального репозитория в проект на githab.
# 1. Разместить на github ранее созданный статический сайт.
# 1. Завершить отчет, добавив описание всех пунктов.

# %% [markdown]
# <a name = '#2'></a>
# ##Цель работы
# <p align="justify">Локальный репозиторий и репозиторий на GitHub</p>

# %% [markdown]
# <a name = '#3'></a>
# ##Задачи работы
#
# 1. Скачать и установить GIT
# 2. Создать локальный репозиторий
# 3. Загрузить файл отчёта в GIT
# 4. Создать профиль на GitHub
# 5. Разместить на GitHub свой статический сайт

# %% [markdown]
# <a name = '#4'></a>
# ## Расчет входных данных

# %% [markdown]
# <font face="times new roman" size="3" color="black">
# В ходе работы были использованы следующие инструменты и материалы:<br>
# 1. Использовавние GIT<br>
# 2. Использование сайта GitHub<br>

# %% [markdown]
# <a name = 'ход_работы'></a>
# # Ход работы

# %% [markdown]
# <a name = 'Задание_№1'></a>
# ## Задание №1
# <font face="times new roman" size="3" color="white">
# <p align="justify">Установить GIT <p>

# %% [markdown]
# <font face="times new roman" size="3" color="white">
# <p align="justify">Чтобы выполнить это задание я зашёл на сайт gitforwindows.org, скачал и установил GIT<p>

# %% [markdown]
# <a name = 'Задание_№2'></a>
# ## Задание №2
# <font face="times new roman" size="3" color="white">
# <p align="justify">Создать локальный репозиторий</p>

# %% [markdown]
# <font face="times new roman" size="3" color="white">
# <p align="justify">
# Для выполнения этого задания я создал папку - GIT на рабочем столе и с помощью команды: git init; создаём локальный репозиторий в нашей созданной папке.</p>
#
# ![Плагин](https://cdn.discordapp.com/attachments/1001872952331075687/1177315462758010920/image.png?ex=65720f77&is=655f9a77&hm=1cf24375486f7236a283571ebbf72310697950bf508ab9bec4e2a9c6fa9fbf6d& "Рисунок 1")

# %% [markdown]
# <a name = 'Задание_№3'></a>
# ## Задание №3
# <font face="times new roman" size="3" color="white">
# <p align="justify">Создать файл отчета по выполнению практической работы и поместить его в репозиторий</p>

# %% [markdown]
# <font face="times new roman" size="3" color="white">
# <p align="justify">
# Для выполнения данного задания я создал файл с названием p3.sql и использовал команды: ALTER TABLE - Служит для изменения макета таблицы после того, как она была создана с помощью инструкции CREATE TABLE, reaname to based_n - меняет имя таблицы с Based на based_n, ADD text_n TEXT - добавляет столбец с названием text_n и типом данных TEXT (Рисунок 5)</p>
#
# ![Плагин](https://cdn.discordapp.com/attachments/1150684055340318782/1170413686469435472/Screenshot_2023-11-04_at_20.25.18.png?ex=6558f3b0&is=65467eb0&hm=e6171345c95716899af32e09d82a6e56ffd4e0f5e118618634955b89fc4bfa7e& "Рисунок 5")
# <p align="justify">Результат выполнения файла можно увидеть на рисунке 6:</p>
#
# ![Плагин](https://cdn.discordapp.com/attachments/1150684055340318782/1170412079207952474/Screenshot_2023-11-04_at_20.19.06.png?ex=6558f230&is=65467d30&hm=c283be2b774d66c9cdd3498a8fb9d135c2fed42ded8a919203672adcf7ecf365& "Рисунок 6")

# %% [markdown]
# <a name = 'Задание_№4'></a>
# ## Задание №4
# <font face="times new roman" size="3" color="white">
# Написать файл для выполнения с расширением .sql для удаления первой таблицы.

# %% [markdown]
# <font face="times new roman" size="3" color="white">
# <p align="justify">
# Чтобы выполнить данное залание я создал файл названием p4.sql и написал в него команду: DROP TABLE Based - удаление таблицы Based</p>
#
# ![Плагин](https://cdn.discordapp.com/attachments/1150684055340318782/1170415911191199854/Screenshot_2023-11-04_at_20.34.39.png?ex=6558f5c2&is=654680c2&hm=af4444f96f2a6f58507922e2d24be497f6aafb498f5c8a91ca0a6795efe1f562& "Рисунок 7")
# <p align="justify">Результат выполнения файла можно увидеть на рисунке 8:</p>
#
# ![Плагин](https://cdn.discordapp.com/attachments/1150684055340318782/1170416447596536060/Screenshot_2023-11-04_at_20.36.54.png?ex=6558f642&is=65468142&hm=f977baeefb6f0819661c22dc39d219dfda54006e7674f6ced7b695a18a0744b2& "Рисунок 8")

# %% [markdown]
# <a name = 'Задание_№5'></a>
# ## Задание №5
# <font face="times new roman" size="3" color="white">
# <p align="justify">Написать файл для выполнения с расширением .sql для заполнения таблиц значениями (10 строк)</p>

# %% [markdown]
# <font face="times new roman" size="3" color="white">
# <p align="justify">Для того, чтобы выполнить это задание я использовал команды: INSERT INTO based_n - применить к таблице based_n к столбцам (number, string, date, boolean) VALUES - значения (1,'str1','2023-11-1',TRUE). Значения нужно указывать в том порядке, в котором распологаются столбцы. Так я прописал 10 раз только с разными значениями (Рисунок 9)</p>
#
# ![Плагин](https://cdn.discordapp.com/attachments/1150684055340318782/1170419314818564096/Screenshot_2023-11-04_at_20.47.37.png?ex=6558f8ed&is=654683ed&hm=b97ecd24e418a05ceb9d0529ac811a47b5426f1d99fcabde0d59bf8ccfccfbb3& "Рисунок 9")
#
# <p align="justify">Результат выполнения файла можно увидеть на рисунке 10:</p>
#
# ![Плагин](https://cdn.discordapp.com/attachments/1150684055340318782/1170422567950094429/Screenshot_2023-11-04_at_21.01.12.png?ex=6558fbf5&is=654686f5&hm=e71138a6be6c02293404a8f9a8fac1a50dcdaa2c88395c9531dc8683289b8528& "Рисунок 10")

# %% [markdown]
# <a name = 'Задание_№6'></a>
# ## Задание №6
# <font face="times new roman" size="3" color="white">
# <p align="justify">Написать файл для выполнения с расширением .sql для удаления строк (3 строки)</p>

# %% [markdown]
# <font face="times new roman" size="3" color="white">
# <p align="justify">1. Для того, чтобы выполнить это задание я использовал следующую команду: DELETE FROM based_n - удалить для таблицы based_n строки WHERE number > 7 - когда число > 7 (Рисунок 11)<br>
#
# ![Плагин](https://cdn.discordapp.com/attachments/1150684055340318782/1170424141829115914/Screenshot_2023-11-04_at_21.07.30.png?ex=6558fd6c&is=6546886c&hm=a127784c1bc10dba5eac0a5c40dc2331ff3c26b4305b2d582d679a971a709679& "Рисунок 11")
# <p align="justify">Результат выполнения файла можно увидеть на рисунке 12:</p>
#
# ![Плагин](https://cdn.discordapp.com/attachments/1150684055340318782/1170424566057816194/Screenshot_2023-11-04_at_21.09.08.png?ex=6558fdd1&is=654688d1&hm=6d3686a03317bc7f438cd4e0f7068829f86bc011e60c0fcdc4bc4f05e1bf2b2d& "Рисунок 12")

# %% [markdown]
# <a name = 'Задание_№7'></a>
# ## Задание №7
# <font face="times new roman" size="3" color="white">
# <p align="justify">Написать файл для выполнения с расширением .sql для вывода содержимого таблицы</p>

# %% [markdown]
# <font face="times new roman" size="3" color="white">
# <p align="justify">1. Для того, чтобы выполнить это задание я использовал команду: SELECT * FROM based_n - эта команда выводит содержимое таблицы (Рисунок 13)</p>
#
# ![Плагин](https://cdn.discordapp.com/attachments/1150684055340318782/1170425996361617488/Screenshot_2023-11-04_at_21.14.50.png?ex=6558ff26&is=65468a26&hm=7e7c1b9c0c64d198a4204d7a55f63a0cb36a5381363bf75e4a5d9bb655bdf7d2& "Рисунок 13")
# <p align="justify">Результат выполнения файла можно увидеть на рисунке 14:</p>
#
# ![Плагин](https://cdn.discordapp.com/attachments/1150684055340318782/1170426301245567078/Screenshot_2023-11-04_at_21.15.56.png?ex=6558ff6f&is=65468a6f&hm=50ac7a8ac72e69834002206f3f312404582b10ce52c646c891c9861414490baa& "Рисунок 14")

# %% [markdown]
# <a name = 'Задание_№8'></a>
# ## Задание №8
# <font face="times new roman" size="3" color="white">
# <p align="justify">Добавить и запустить на выполнение все файлы в интерфейсе phpMyAdmin</p>

# %% [markdown]
# <font face="times new roman" size="3" color="white">
# <p align="justify">Чтобы выполнить это задание я зашёл на phpMyAdmin и загрузил файл и далее я запустил его. Аналогично я сделал со всеми файоами (Рисунок 15)</p>
#
# ![Плагин](https://cdn.discordapp.com/attachments/1001872952331075687/1170428262376292393/Screenshot_2023-11-04_at_21.23.15.png?ex=65590143&is=65468c43&hm=1ea9438ce64a6951e359d3c65b77ce871caedaa9a6f3651782ce318ae945ac23& "Рисунок 15")

# %% [markdown]
# <a name = 'Результат_выполнения'></a>
# # Результат выполнения работы

# %% [markdown]
# <font face="times new roman" size="3" color="white">
# <p align="justify">
# Смотреть: Рисунок 16
#
# ![Плагин](https://cdn.discordapp.com/attachments/1001872952331075687/1170428874174234827/Screenshot_2023-11-04_at_21.26.16.png?ex=655901d5&is=65468cd5&hm=2b2c1c2f36ad1761f47ddfe9edeb6e48326aee3ab204dabaa8539ad748ed16ef& "Рисунок 16")
# <br><br>
# </p>

# %% [markdown]
# <a name = 'Контрольное_задание'></a>
# # Контрольное задание на защиту
